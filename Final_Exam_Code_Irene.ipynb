# %% [markdown]
# https://www.kaggle.com/c/cs5785-fall19-final/

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import csv

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train_feat = pd.read_csv("cs5785-fall19-final/features_train/features_resnet1000_train.csv", header = None, index_col=None)
train_feat_inter = pd.read_csv("cs5785-fall19-final/features_train/features_resnet1000intermediate_train.csv", header = None, index_col=None)

# %%
train_feat
# Out:
#                        0         1         2         3         4         5     \
# 0     images_train/5373.jpg -0.899450 -0.930470 -2.503365 -3.172499 -2.819133
# 1      images_train/984.jpg -1.346954 -3.119461 -0.765971 -1.382550 -1.104675
# 2     images_train/7127.jpg -3.445498 -1.524573 -1.001654 -3.668335 -1.805517
# 3     images_train/9609.jpg  1.114650 -2.167102  0.097881 -1.336255  0.853483
# 4     images_train/5293.jpg  1.602650 -1.505817  3.029409  4.092412  1.711755
# ...                     ...       ...       ...       ...       ...       ...
# 9995   images_train/280.jpg -0.383104 -1.147527 -0.767162  0.560305  1.351023
# 9996  images_train/3026.jpg  0.227993 -2.812512 -2.020288 -3.084338 -3.726762
# 9997  images_train/3061.jpg -2.902884 -0.982832 -1.992587 -0.087052 -1.207096
# 9998  images_train/3290.jpg  0.112402  1.814938 -2.223123 -3.056098 -1.655839
# 9999  images_train/2745.jpg -0.855339 -0.572401 -2.435775  0.926859 -0.953390
#
#           6         7         8         9     ...      991       992   \
# 0     0.992159 -3.698863  0.619991  0.956148  ... -3.021916  2.214253
# 1    -3.656271 -4.815436 -0.556942 -1.402286  ...  0.011003 -3.968805
# 2    -1.633496 -7.127826 -1.147802 -1.055816  ... -2.991777 -2.628053
# 3    -0.374885 -2.369090 -2.273191 -1.143788  ... -1.248134 -0.633126
# 4     6.271253  4.173686 -2.177313  0.747789  ... -1.285806 -2.266481
# ...        ...       ...       ...       ...  ...       ...       ...
# 9995  1.128219 -1.335513 -0.951826 -2.833633  ...  0.729406 -1.277902
# 9996  0.686132 -3.396905 -1.242543 -1.237810  ... -1.860951 -2.085487
# 9997  0.473697 -1.746261 -1.321257 -0.779796  ... -1.879170 -1.827772
# 9998  2.840378 -2.344636 -1.500102 -2.022258  ...  4.475745  2.290951
# 9999 -0.673999 -4.573103  1.334293  0.786952  ...  0.341109 -1.082773
#
#           993       994       995       996       997       998       999   \
# 0    -1.382491  1.672911  1.014233  2.599949  2.773284 -2.066632  0.385754
# 1    -2.694711 -4.196480 -2.880234 -1.210742 -1.605143 -4.859987 -0.837670
# 2    -2.971074 -2.537039 -1.707429  1.013672  0.608460 -3.714998 -0.484735
# 3    -1.723514 -2.638832  0.097149  4.647974  1.030138 -2.193836  1.044024
# 4    -3.898053  2.295787 -1.749552  0.974188  1.258117 -1.975622 -1.278643
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -3.523198 -2.746163 -1.212599  0.954832 -0.452879 -3.665162  1.875660
# 9996 -2.565209 -1.050840 -1.358280  0.206889  1.172924 -1.504285  1.075150
# 9997 -2.372616 -1.339709 -1.408373  1.573033  3.866848 -1.905706  1.044854
# 9998  0.425016  3.263029  2.560808  4.265704  5.859500  3.286212  5.585330
# 9999 -2.808898 -1.564210 -0.096841  1.729478  0.587778 -1.071101  4.155492
#
#           1000
# 0    -3.241320
# 1    -0.967604
# 2     0.138767
# 3     0.176043
# 4    -1.941441
# ...        ...
# 9995 -0.085844
# 9996 -0.358825
# 9997  0.048946
# 9998 -2.660409
# 9999 -2.685419
#
# [10000 rows x 1001 columns]

# %%
train_feat_inter
# Out:
#                        0         1         2         3         4         5     \
# 0     images_train/5373.jpg  0.460352  1.018530  0.283533  0.053866  1.071661
# 1      images_train/984.jpg  1.498549  0.295754  0.266695  0.265754  0.793800
# 2     images_train/7127.jpg  0.460160  0.570405  0.535643  0.073016  0.158414
# 3     images_train/5293.jpg  0.626306  0.095554  0.175943  0.096139  0.063999
# 4     images_train/3688.jpg  0.253012  1.743208  0.359000  0.486566  0.473813
# ...                     ...       ...       ...       ...       ...       ...
# 9995  images_train/1513.jpg  0.535642  0.687255  0.083333  0.300942  0.191898
# 9996   images_train/280.jpg  1.246803  0.158779  0.069608  0.239203  0.339317
# 9997  images_train/3026.jpg  0.795082  0.050375  0.514682  0.149355  0.296212
# 9998  images_train/3061.jpg  0.218087  0.455968  0.180336  0.638798  0.020036
# 9999  images_train/2745.jpg  0.662753  0.300961  0.368162  0.428124  0.201122
#
#           6         7         8         9     ...      2039      2040  \
# 0     0.017668  0.330733  0.092461  0.611386  ...  0.164259  0.422783
# 1     0.115943  0.237539  0.612437  1.229246  ...  0.421009  0.462610
# 2     0.391194  0.088051  1.249013  0.032401  ...  0.232817  0.338647
# 3     0.761737  0.107138  0.120813  1.628744  ...  0.157466  0.148046
# 4     0.141680  0.164890  0.533619  0.268889  ...  0.317842  0.260543
# ...        ...       ...       ...       ...  ...       ...       ...
# 9995  0.061594  0.094673  0.261326  0.175985  ...  0.122387  0.258693
# 9996  0.654636  0.431270  0.342523  0.058934  ...  1.408242  0.095201
# 9997  0.055376  0.005658  0.178999  0.126511  ...  0.105775  0.182315
# 9998  0.005852  0.002596  0.491824  0.992739  ...  0.003265  0.378536
# 9999  0.620914  0.210089  0.578182  0.172338  ...  0.382797  0.284732
#
#           2041      2042      2043      2044      2045      2046      2047  \
# 0     0.592163  0.349664  0.130692  0.245438  0.021640  0.412349  0.443392
# 1     0.552496  0.138283  0.205361  0.343715  0.160027  0.172050  0.106674
# 2     0.925935  0.150575  0.220055  0.008997  0.135737  0.325504  0.006667
# 3     1.304605  0.556068  0.032862  0.906909  0.105638  0.230118  0.785661
# 4     0.374608  0.043875  0.453899  0.265805  0.106244  0.038468  0.539088
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.671753  0.023723  0.003821  0.015286  0.088165  0.069943  0.125865
# 9996  0.388780  0.093607  0.119105  0.230212  0.156429  0.175575  0.026569
# 9997  1.141507  0.121821  0.241242  0.065257  0.492455  0.334923  0.706268
# 9998  0.367421  0.186446  0.012345  0.063488  0.104821  0.280519  0.048519
# 9999  0.480949  0.235079  0.203599  0.230940  0.212722  0.227641  0.458274
#
#           2048
# 0     0.035718
# 1     0.054805
# 2     0.432770
# 3     0.175187
# 4     0.176292
# ...        ...
# 9995  0.454817
# 9996  0.827043
# 9997  0.437172
# 9998  0.468362
# 9999  1.613738
#
# [10000 rows x 2049 columns]

# %%
img=mpimg.imread("cs5785-fall19-final/{}".format(train_feat[0][0]))
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# -----

# %% [markdown]
# ### Import files

# %%
descriptions = []
for i in range(10000):
    with open(('cs5785-fall19-final/descriptions_train/{}.txt').format(i), newline='') as f:
        desc1 = []
        reader = csv.reader(f)
        for row in reader:
            desc1.append(row)
        descriptions.append(desc1)

# %%
descriptions
# Out:
# [[['The skateboarder is putting on a show using the picnic table as his stage.'],
#   ['A skateboarder pulling tricks on top of a picnic table.'],
#   ['A man riding on a skateboard on top of a table.'],
#   ['A skate boarder doing a trick on a picnic table.'],
#   ['A person is riding a skateboard on a picnic table with a crowd watching.']],
#  [['A bowl of soup that has some carrots', ' shrimp', ' and noodles in it.'],
#   ['The healthy food is in the bowl and ready to eat. '],
#   ['Soup has carrots and shrimp in it as it sits next to chopsticks.'],
#   ['A tasty bowl of ramen is served for someone to enjoy. '],
#   ['Bowl of Asian noodle soup', ' with shrimp and carrots.']],
#  [['A man who is walking across the street.'],
#   ['A busy intersection with an ice cream truck driving by.'],
#   ['a man walks behind an ice cream truck '],
#   ['A man is crossing a street near an icecream truck.'],
#   ['The man is walking behind the concession bus.']],
#  [['A young boy throwing a frisbee in a grassy field'],
#   ['a young boy in the park throwing a frisbee'],
#   ['A young boy throws a frisbee in a tree lined park.'],
#   ['A kid in a city park throws a bright green Frisbee. '],
#   ['A boy throwing a green frisbee in a grass field.']],
#  [['A young child in the yard holding up a bat.'],
#   ['A boy raring back with a baseball bat in a yard.'],
#   ['A little boy has a baseball bat in a yard.'],
#   ['A boy in black clothes holds a baseball bat over his shoulder near a fence and a tree.'],
#   ['a little boy playing in his yard with a baseball bat']],
#  [['A small bedroom with a desk and computer in it.'],
#   ['A bedroom that has a desk', ' chair', ' and bed in it.'],
#   ['A chair sitting in front of a brown desk.'],
#   ['A desk beside a window in a bedroom'],
#   ['a bed and a desk and chair by a big window']],
#  [['A small child is eating a donut fed by another hand.'],
#   ['A blonde boy looking at his donut hole.'],
#   ['A boy is looking at a small doughnut with powdered sugar on his face.'],
#   ['A little boy eating powered sugar covered flood.'],
#   ['a child eats part of a sugar frosted donut']],
#  [['a man is standing in the woods wearing a hat and glasses'],
#   ['A man in sunglasses wears a grass tie and hat.'],
#   ['A man wearing a woven crown and tie.'],
#   ['a man in a blue shirt with some weird crown'],
#   ['a man that is standing around in a hate']],
#  [['this is a street with a brick building'],
#   ['a building with a sign and a street right outside'],
#   ['Black and white image of an empty street. '],
#   ['a old building that is next to a street'],
#   ['A black and white picture of a building']],
#  [['A tent in a forest next to a silver and brown RV.'],
#   ['a camp site and a trailer on the road'],
#   ['Two pictures of a tent and a bus.'],
#   ['Two juxtaposed pictures show a tent and a motor home.'],
#   ['There is a tent with a photo of a bus under it.']],
#  [['A bunch of luggage laying on an area rug. '],
#   ['Several pieces of luggage on a floor with an area rug.'],
#   ['The luggage is sitting on top of the persian rug.'],
#   ['a bunch of travel bags sit on a carpet floor '],
#   ['Several pieces of luggage that are laying on the floor.']],
#  [['A baseball player holding a bat next to a base.'],
#   ['A photo of a baseball game where a guy is at home plate taking a pitch.'],
#   ['A baseball player attempts to hit a baseball',
#    ' while a catcher and umpire watch.'],
#   ['people on a field playing baseball and other watching'],
#   ['A baseball player holding a bat and a catcher squatting behind him. ']],
#  [['A group of four street signs stacked on top of each other.'],
#   ['four sign streets set on a blue background'],
#   ['there are 4 traffic sigs of the United Kingdom'],
#   ['A road sign giving directions to four streets'],
#   ['The old street signs are on display. ']],
#  [['A Boston Red Sox player up to bat.'],
#   ['The stands are filled with people as an umpire stands behind a catcher and a man with a black helmet holds a bat.'],
#   ['A baseball batter looking down the first base line in front of a crowd.'],
#   ['A group of men on a field playing baseball.'],
#   ['a crowd of people watching men play a baseball game ']],
#  [['A car driving through a tunnel under buildings'],
#   ['Car passing through a very small tunnel in a city street. '],
#   ['A car driving through a tunnel between two buildings.'],
#   ['A tunnel in the middle of a street with a car about to go down it'],
#   ['A car is driving through a tunnel in a city street.']],
#  [['Several people are standing at a table looking at wine bottles.'],
#   ['A woman standing in front of a table surrounded by a crowd of people.'],
#   ['A group of people at a table filled with wine bottles'],
#   ['Eager people standing in front of tables at an exhibition.'],
#   ['several people looking at many bottles of wine']],
#  [['a very tall brown structure sitting above a parking lot.'],
#   ['A red brick school building with a student walking towards the building. '],
#   ['A pair of buildings from a very far away view.'],
#   ['People with backpacks walking around big brown buildings that look like college.'],
#   ['A cluster of school buildings rise tall in the foreground as students walk to school.']],
#  [["The image shows a series of a snowboarder's descent down the slope. "],
#   ['A photograph of several images of the same young man ridding a snowboard through the woods.'],
#   ['A time lapse image of a snowboarder gliding forward'],
#   ['Six people are snow boarding down the hill.'],
#   ['A bunch of different images of a man on a snowboard.']],
#  [['A group of kids at table around a cake.'],
#   ['A group of kids around a table with a cake.'],
#   ['A group of kids watching a woman light a candle.'],
#   ['A group of young children standing around a cake.'],
#   ['little kids sitting around a table that has a birthday cake on it']],
#  [['A yellow and white train traveling past a train station.'],
#   ['A small train going down the train track.'],
#   ['A single train car stopped at a small station.'],
#   ['A large long train on a steel track.'],
#   ['Single commuter train car at a rail station.']],
#  [['A cat sitting in front of a large computer monitor.'],
#   ['A kitten is trying to interact with a kitten that is on television.'],
#   ['A cat curiously looks at a photo of a cat on a computer screen'],
#   ['A cat looking at another cat on the television.'],
#   ['A cat sitting in front of a monitor that is displaying a picture of another cat.']],
#  [['A clock statue surrounded by city traffic and streets.'],
#   ['A car on a street in front of a building.'],
#   ['A car parked by a large clock tower.'],
#   ['A clock tower in a European city looks down at the traffic below.'],
#   ['A tall building with a clock embedded at its top.']],
#  [['Two giraffes standing around in the middle of a field.'],
#   ['Two giraffes standing on a dirt expanse with trees in background.'],
#   ['Two giraffes standing out in the hot sun in front of a tent.'],
#   ['Two giraffes standing in a dry landscape gaze to the side. '],
#   ['Two giraffes standing in a desert like area. ']],
#  [['A snowboarder crouching on his board in mid air.'],
#   ['A snowboarder and his board caught mid flight'],
#   ['A man flying through the air while riding a snowboard.'],
#   ['A snowboarder jumping a hill on a snowy mountain.'],
#   ['A snowboarder grabs the back of her snowboard while jumping']],
#  [['A group of cars that are driving passed a church.'],
#   ['A chirch is littered with cars in its parking lot'],
#   ['A church is sitting in the background with automobiles driving in front of it.'],
#   ['A tall red brick cathedral with two large towers.'],
#   ['a line of cars are oarked outside an old church']],
#  [['A small bed laying on top of a table.'],
#   ['A bird stting on what appears to be a piece of machinery. '],
#   ['Small bird with fluffy feathers sitting in nest'],
#   ['a small bird with its head pulled back'],
#   ['A newborn baby bird sitting quietly by itself ']],
#  [['A picture of a dog laying on the ground.'],
#   ['Dog snoozing by a bike on the edge of a cobblestone street'],
#   ['The white dog lays next to the bicycle on the sidewalk.'],
#   ['a white dog is sleeping on a street and a bicycle'],
#   ['A puppy rests on the street next to a bicycle.']],
#  [['a man riding a surfboard close to the shore '],
#   ['A surfer riding a wave onto the beach with multiple surfers behind him.'],
#   ['A man riding a wave on top of a surfboard.'],
#   ['A surfer riding a wave with other surfers in the background.'],
#   ['There were several people out in the surf today with their boards.']],
#  [['A computer monitor sitting on top of a desk.'],
#   ['A picture of a screen in the living room. '],
#   ['A computer is lit up on the checkout counter.'],
#   ['a desk with a monitor and a person holding a laptop'],
#   ['Part of a computer screen in front of a laptop.']],
#  [['Bikes lined up at a bike stop with an advertisement near by that says "your butts"'],
#   [],
#   ['A few bikes are arranged by a bike lock'],
#   ['Two bikes are chained to bike racks on a city street'],
#   ['Two bicycles locked into bike parking stands on a sidewalk.'],
#   ['A pair of bicycles are parked in a designated area.']],
#  [['A group of young ladies playing a game of soccer.'],
#   ['Four girls are playing soccer in the field. '],
#   ['A few women on a field playing soccer'],
#   ['Girls kicking the ball and running playing competitive soccer.'],
#   ['A group of girls playing soccer against each other.']],
#  [['a close up of a stuffed animal near car pedals '],
#   ['a tan teddy bear and a gas and brake pad'],
#   ['A stuffed bear sits on the floorboard of a vehicle. '],
#   ['A teddy bear positioned to look as though he is pushing the gas pedal in a vehicle. '],
#   ['A very cute stuffed animal with its foot on a gas pedal.']],
#  [['A beautiful young lady talking on a phone while smiling.'],
#   ['A woman with a lanyard and name tag while on a cell phone.'],
#   ['A woman standing in a corner by a curtain taking a cell phone call. '],
#   ['A woman smiling while talking on her cell phone. '],
#   ['A woman is sitting in a corner talking on the telephone.']],
#  [['several dogs behind a crate with hay on the ground'],
#   ['Four hounds peek out from behind a latticed gate. '],
#   ['ALL THOSE HUNTING DOGS READY FOR THE CASE.'],
#   ['The beagles are penned in',
#    ' but two have pushed their heads through the openings in the splintery wood slats.'],
#   ['Two brown and white dogs standing next to each other a fence.']],
#  [['A woman standing on a tennis court holding a racquet.'],
#   ['A woman picking up a ball with a tennis racquet.'],
#   ['Three people with racquets stand on a tennis court. '],
#   ['a person with a tennis racket picks up a tennis ball '],
#   ['A woman tries to scoop a tennis ball with her racket.']],
#  [['Two containers filled with food and sweets on a table.'],
#   ['A sandwich bun', ' lunchmeat', ' and grapes are served in a lunch box.'],
#   ['a dinner tray set up with a sandwich grapes and cheese'],
#   ['The lunch set up includes a variety of foods.'],
#   ['Two containers on a table holding grapes', ' salami and a bun. ']],
#  [['Large motorcycle sitting on a grassy area in a line.'],
#   ['Older motorcycle displayed on grass along with several old cars.'],
#   ['A motorcycle that is parked in a field.'],
#   ['Several motorcycles and cars sitting on a grassy lot'],
#   ['A number of motorbikes and cars parked in the field']],
#  [['A kitchen scene with focus on the refrigerator.'],
#   ['A fridge that is silver and in a kitchen.'],
#   ['A kitchen contains a large refrigerator with a freezer below it. '],
#   ['Stainless steel fridge in the kitchen of a home.'],
#   ['A kitchen with a large', ' newer looking refridgerator.']],
#  [['A tall tower with a clock stands above a winter sky.'],
#   ['There is a tree next to the clock tower.'],
#   ['A large clock tower on a cloudy winter day. '],
#   ['There is a clock in the center of a tower.'],
#   ['a tower that will have a large clock at the top']],
#  [['Fresh red and yellow tulips in a vase.'],
#   ['Red and yellow tulips are in a vase on a table.'],
#   ['A vase filled with yellow and red flowers.'],
#   ['A vase of tulips sitting in the middle of a table.'],
#   ['A picture of a vase of colorful flowers on a table. ']],
#  [['A surfboard that is on its side in the sand.'],
#   ["A lifeguard's surf board on the beach near the surf."],
#   ['A person is standing on the beach near a lifeguard board. '],
#   ['A lifeguard surf board laying on its side near a shoreline.'],
#   ['Group of people walking in front of a white surfboard by the beach. ']],
#  [['A young girl in a bright dress rides a horse.'],
#   ['A girl in a pink dress sitting on top of a horse. '],
#   ['A little girl riding on a brown horse.'],
#   ['A little girl holds onto her saddle as she sits on a horse.'],
#   ['A young girl wearing a helmet riding a horse.']],
#  [['A loft bed with a dresser underneath it.'],
#   ['A bed and desk in a small room.'],
#   ['Wooden bed on top of a white dresser.'],
#   ['A bed sits on top of a dresser and a desk.'],
#   ['Bunk bed with a narrow shelf sitting underneath it. ']],
#  [['A couple of birds standing on top of  a wooden bench.'],
#   ['Pair of wild birds standing on dock at waterway area.'],
#   ['a couple of birds standing on a dock '],
#   ['Two herons on a wharf facing each other and water in the background.'],
#   ['Two birds standing on a bench near the water ']],
#  [['Two giraffes in a room with people looking at them.'],
#   ['Two giraffe standing next to each other in a room.'],
#   ['The giraffe is being kept by itself indoors. '],
#   ['A man and woman staring at two giraffes through a window.'],
#   ['a giraffe in a enclosed area is watched by some people']],
#  [['A woman stands in the dining area at the table.'],
#   ['A room with chairs', ' a table', ' and a woman in it.'],
#   ['A woman standing in a kitchen by a window'],
#   ['A person standing at a table in a room.'],
#   ['A living area with a television and a table']],
#  [['A full view of a shower with glass.'],
#   ['A walk in shower with a hand held shower head.'],
#   ['A bathroom shower stall with a shower head.'],
#   ['a glass walled shower in a home bathroom'],
#   ['a see through glass shower in a bathroom ']],
#  [['Birds perch on a bunch of twigs in the winter.'],
#   ['A number of small birds sitting at the top of a bare tree.'],
#   ['Many birds perched on the limbs of a tree.'],
#   ['Eight birds perch on a branch on an overcast day.'],
#   ['Several birds are sitting on small tree branches.']],
#  [['a wood bench sitting in a park with three people sitting on it '],
#   ['a mother and her two children sit on a green bench'],
#   ['A lady with two children sitting on a park bench.'],
#   ['A woman and two young children sit on a bench.'],
#   ['A woman and two children on a wooden bench in an open parkland']],
#  [['Black and white picture of guy and girl in an embrace on a park bench.'],
#   ['A romantic couple smooching on a park bench',
#    ' traffic and pedestrians behind them.'],
#   ['A man kissing a woman while they sit on a bench on a sidewalk.'],
#   ['A man hugging a woman as they sit on a bench on the street with people walking behind them on the sidewalk.'],
#   ['A sitting on a bench and kissing woman on  the check as people pass by.']],
#  [['A woman in a tie and blue hair. '],
#   ['A woman with dyed purple hair wearing a black shirt and spotted tie'],
#   ['a woman with blue hair wearing a tie'],
#   ['A woman in a black dress shirt and tie with purple hair. '],
#   ['A person with a shade of purple hair and wearing a dark dress shirt and necktie.']],
#  [['A large decorated bus has a couple of folks standing by it. '],
#   ['A bus parked beside a building in a parking lot.'],
#   ['a bus loading and unloading passengers in a parking lot'],
#   ['A large bus sitting next to a very tall building.'],
#   ['Three people looking at a bus parked in a parking space.']],
#  [['A small kitchen with low a ceiling '],
#   ['A small kichen area with a sunlight and and angled ceiling.'],
#   ['an image of a kitchen loft style setting'],
#   ['a small kitchen with a lot of filled up shelves '],
#   ['A kitchen with a slanted ceiling and skylight.']],
#  [['Two people are at a computer desk with a mouse.'],
#   ['A man sitting at a table using a laptop computer.'],
#   ['A woman is typing on a laptop on a wooden table.'],
#   ['A woman types on a laptop while someone else operates the mouse.'],
#   ['two arms typing on a laptop and one hand on a mouse']],
#  [['A man using his laptop at his desk'],
#   ['A man sitting at a desk on a laptop computer.'],
#   ['a man sitting at a desk using his laptop '],
#   ['an image  of a man working on his laptop'],
#   ['A man is looking slyly at the camera while sitting at his laptop at a desk.']],
#  [['A baby girl sitting on top of a green grass holding a cell phone.'],
#   ['Cute little kid smiling while holding a cell phone'],
#   ['A baby sitting on a picnic blanket in a park holding a cellphone.'],
#   ['A toddler holds a cellphone while sitting in a park.'],
#   ['an older baby sits in a grassy field',
#    ' holding a cell phone to its face']],
#  [['a full frontal view of a giraffe and an ostrich behind'],
#   ['A giraffe with an ostrich in the background on a field of grass next to statues.'],
#   ['A giraffe bent at the shoulders with its neck stretched out.'],
#   ['a giraffe on some grass in its pen at the zoo'],
#   ['there is a giraffe in a zoo along with a ostrich also']],
#  [['A bowl that has various types of food in it.'],
#   ['A white bowl filled with broccoli and carrot slices.'],
#   ['A serving of broccoli and carrots in a white dish.'],
#   ['Broccoli and carrots shown in white serving dish.'],
#   ['Some of the broccoli in this bowl are starting to yellow. ']],
#  [['A woman looking straight ahead while she wears a hat on her head. '],
#   ['a lady that has  a grey hat on her head'],
#   ['A woman in a black shirt is posing with a hat on her head.'],
#   ['a women posing in a fashionable hat and shirt '],
#   ['A young adult female in hat and black v neck is looking into the camera.']],
#  [['A group of baseball players is crowded at the mound.'],
#   ['A baseball player at the area where one goes to bat '],
#   ['A man that is standing in the dirt near a plate.'],
#   ['a baseball player on the home plate during a game'],
#   ['A baseball player for the Chicago Cubs stands at home plate.']],
#  [['A  large air plane flying in the blue sky.'],
#   ['A plane is flying in the air against a blue sky.'],
#   ['A plane is flying in the blue sky.'],
#   ['Large white jet airplane flying through clear blue skies. '],
#   ['A jumbo jet plane flying through a cloudless blue sky.']],
#  [['A passenger train that has had some graffiti written on it.'],
#   ['A train with graffiti painted over the door.'],
#   ['A red and white train care with graffiti on its doors.'],
#   ['A passenger train marred with graffiti pauses at a station. '],
#   ['The train door has been painted colorfully above the entrance.']],
#  [['This table is filled with a variety of different dishes.'],
#   ['A variety of food in dishes is displayed on a table.'],
#   ['Table of food including carrots',
#    ' peas',
#    ' salad',
#    ' corn',
#    ' gravy',
#    ' pies',
#    ' bread'],
#   ['A table layed out with food such as',
#    ' salad',
#    ' steamed peas and carrots',
#    ' steamed corn',
#    ' and bread rolls.'],
#   ['A table full of food such as peas and carrots',
#    ' bread',
#    ' salad and gravy. ']],
#  [['A grey and white dog sitting in the passenger side of a car.'],
#   ['Beautiful husky sitting up in the front passenger seat'],
#   ['A husky riding in the front seat of the car'],
#   ['A husky dog sitting on the front seat of a car'],
#   ['A dog looks interested as he sits in the front seat of a car.']],
#  [['A metal bench between two white flowering bushes.'],
#   ['A garden containing white flowers and a black bench.'],
#   ['a bench sits inside of a garden with flowers '],
#   ['There is a walkway lined with white flowers'],
#   ['A gray mesh park bench sitting in a peaceful setting surrounded by flowers and plants.']],
#  [['A bakery with customer at the counter and various types of donuts in the display case in front of the customers.'],
#   ['People are standing behind the bakery counter. '],
#   ['Ladies in a doughnut shop looking for a treat. '],
#   ['Women standing in front of bakery case with doughnuts'],
#   ['A lot of donuts that are in a tray.']],
#  [['A room is shown with a bed and luggage.'],
#   ['A suitcase that is in a empty bedroom.'],
#   ['A luggage bag is next to a dresser in a bedroom. '],
#   ['A suitcase sitting in a hotel room with a king size bed.'],
#   ['A large wooden piece of furniture next to a piece of luggage.']],
#  [['Two giraffes with necks crossed in the distance.'],
#   ['two giraffes with their necks crossed in a field '],
#   ['Two giraffes are walking together in the open field'],
#   ['Two giraffes with their necks crossed in a plain.'],
#   ['A couple of giraffe standing next to each other.']],
#  [['a group of pictures with baseball players in it'],
#   ['A man standing on a baseball field talking to a child on the pitchers mound.'],
#   ['Coach telling young pitcher what to do with the baseball'],
#   ['In side-by-side photos',
#    " a uniformed adult coach engages with a child on a baseball diamond's pitching mound and the child player stands alone in the next picture with the ball in hand at his chest and gloved hand at his side."],
#   ['A child is talking to a man at a baseball game.']],
#  [['A group of people sitting and standing around a table with beverages.'],
#   ['six seven persons are enjoying a drink party.'],
#   ['A group of friends chatting around a square table with drinks.'],
#   ['A group of men and women are sitting at a table full of bottles and glasses of beverages. '],
#   ['Many people are hanging out at their table with some drinks. ']],
#  [['A person is organizing food on to platters'],
#   ['A person standing over a plate of vegetables holding a bowl filled with green paste.'],
#   ['A man preparing a vegetable plates for consumption.'],
#   ['A person prepares her vegetables on a plate.'],
#   ['A person putting a sauce on two plates full of greens',
#    ' carrots and tomatoes.']],
#  [['A fire hydrant is placed in a wooded area'],
#   ['A red teddy bear standing in a forest on dry grass.'],
#   ['Picture of a fire hydrant in front of a large group of trees. '],
#   ['Red fire hydrant next to fence and trees.'],
#   ['A red fire hydrant placed by a broken fence and trees']],
#  [['A vase filled with flowers and water on top of a table.'],
#   ['Clear vase with pink roses in it on a wooden table.'],
#   ['Pink flowers sitting in a flower pot full of water. '],
#   ['A vase of carnations on a table outside '],
#   ['this clear vase has many pink flowers in it']],
#  [[' A bald man holding a blue umbrella on a street.'],
#   ['a man protecting himself from rain and watching'],
#   ['A man looks to his left while holding a blue umbrella on a rainy day in the street.'],
#   ['A man waits by the street with an open umbrella in his hand.'],
#   ['A man standing on the sidewalk with a blue umbrella.']],
#  [['An aerial view of a train on train tracks.'],
#   ['A train on a train track next to a grassy area.'],
#   ['a top view of a train riding on some tracks '],
#   ['The aerial photo shows a train viewed from above.'],
#   ['A train runs parallel to the other tracks.']],
#  [['A cat laying on top of a bag sitting on a floor.'],
#   ['A Tabby cat laying on top of a black backpack.'],
#   ['The orange and grey cat is lying down on a black backpack. '],
#   ['stripped cat on top of a black suitcase'],
#   ['A cat that is laying down on a bag.']],
#  [['Many brightly colored umbrellas hanging downward from a domed ceiling.'],
#   ['Chandeliers of an atrium in a building are decorated with flowers.'],
#   ['A ceiling with lots of colorful umbrellas hanging from it.'],
#   ['A domed ceiling is decorated with umbrellas that have bright red and yellow flowers on them.'],
#   ['Flower umbrellas hanging upside down inside a room.']],
#  [['a man standing holding a game controller and two people sitting'],
#   ['Young adult using video game controller with other looking on.'],
#   ['A man standing on a piece of equipment for a video game while holding the remote as four other people look on'],
#   ['people sitting around watching a man playing a video game'],
#   ['The group of friends is enjoyingplaying the video games.']],
#  [['a white bathroom with a toilet and a roll of toilet paper'],
#   ['This toilet bowl is placed directly at the edge of the bathroom.'],
#   ['A bathroom contains a toilet and roll of toilet paper. '],
#   ['A white toilet sitting in the corner of a small bathroom.'],
#   ['An open white toilet next to toilet paper in a bathroom']],
#  [['An open roofed',
#    ' double-decker tour bus displaying a vivid ad across one side enters a downtown intersection.'],
#   ['A red double decker tour bus decorated with a blue ad drives down the street.'],
#   ['A double decker bus with a very large ad. '],
#   ['A large extended blue bus going through an intersection.'],
#   ['A double decker bus with advertising on the side ']],
#  [['A person is holding a pan full of donuts with blue icing.'],
#   ['A tray icing covered donuts while a person in a kitchen.'],
#   ['Doughnuts with frosting are being made in the kitchen'],
#   ['a tray of doughnuts with white icing on it'],
#   ['Glazed doughnuts on cookie sheet near doughnut machine.']],
#  [['a man wearing a red tie holding it up to show people.'],
#   ['A man wearing a suit and maroon tie smiles at other people.'],
#   ['A man is showing a tie emblem at an outdoor event.'],
#   ['The older man is showing off the design on his tie. '],
#   ['a man showing off his tie to someone off camera ']],
#  [['A white sink in a corner underneath a small mirror and light.'],
#   ['A white sink sitting under a mirror in a bathroom.'],
#   ['An all white bathroom consisting of a mirror and sink view.'],
#   ['A bathroom with sink', ' mirror', ' and lights in it.'],
#   ['An all-white bathroom with a light fixture and small mirror above a sink']],
#  [['Motorcycle parked along the street next to a building.'],
#   ['a motorcycle parked next to other motorcycles on city street'],
#   ['A motorcycle is parker on a city sidewalk. '],
#   ['a black motorcycle is on display with more on either side'],
#   ['A parked motorcycle is parked on a city street.']],
#  [['A cat is sitting on top of a computer chair which is covered in hair.'],
#   ['A long haired cat on the top of an office chair covered in cat hair.'],
#   ['A cat laying on the top of a chair that is covered in cat hair.'],
#   ['A cat is sitting atop of a hair chair.'],
#   ['A view of a cat getting fur all over a chair.']],
#  [['This wire metal rack holds several pairs of shoes and sandals'],
#   ['A dog sleeping on a show rack in the shoes.'],
#   ['Various slides and other footwear rest in a metal basket outdoors.'],
#   ['A small dog is curled up on top of the shoes'],
#   ['a shoe rack with some shoes and a dog sleeping on them']],
#  [['There is a small bus with several people standing next to it.'],
#   ['people standing besides a bus taking to each other'],
#   ['People eating from food trucks near a commemorative archway'],
#   ['Several people walking on a sidewalk near a large arch with figures on it.'],
#   ['A very big pretty arch way with a bunch of people near it.']],
#  [['A group of children surrounding a table decorating cake.'],
#   ['a number of children at a table with cake'],
#   ['A group of kids cutting into a cake as one boy plays with his utensil.'],
#   ['Kids around a table messily frosting a sheet cake.'],
#   ['A bunch of kids eating a cake with green frosting on it.']],
#  [['The green and yellow train is rounding the bend of a track.'],
#   ['A green and yellow train going up an incline in the snow.'],
#   ['A train is traveling on the railroad next to the snow. '],
#   ['A train coming out of an enclosure under a snowy mountain.'],
#   ['there is a train coming up the tracks']],
#  [['historical buildings and people walking in the streets'],
#   ['A BIG BUILDING WITH A HUGE CLOCK IN THE MIDDLE OF IT.'],
#   ['A clock is shown on the side of a building.'],
#   ['People are standing on the street in front of a building with a clock.'],
#   ['people walking on a street with a clock on a building']],
#  [['A group of people sitting around a table.'],
#   ['this is a group of people eating a meal'],
#   ['a group of people sitting around a big restaurant table '],
#   ['A group of people sitting at a table that has food on it.'],
#   ['The group of people are sitting together eating.']],
#  [['A marine filled with boats floating on water.'],
#   ['A crowded harbor with seagulls under a cloudy sky.'],
#   ['A white bird flying through a boat-filled harbor.'],
#   ['Many ships are docked in the crowded marina.'],
#   ['A boat dock and harbor with a number of boats tied off to the dock.']],
#  [['A bottle on wine next to a glass of wine.'],
#   ['A glass table with a bottle and glass of wine next to a chair.'],
#   ['A bottle and glass on red wine on a patio table'],
#   ['A glass of champagne next to the champagne bottle.'],
#   ['A glass of wine is shown wit a wine bottle right next to it on a table. ']],
#  [['A big burly grizzly bear is show with grass in the background.'],
#   ['The large brown bear has a black nose.'],
#   ['Closeup of a brown bear sitting in a grassy area.'],
#   ['A large bear that is sitting on grass. '],
#   ["A close up picture of a brown bear's face."]],
#  [['Three giraffe and a wildebeest in a field.'],
#   ['A moose and several giraffes are grazing in the field.'],
#   ['Zebras in the wild with a wildebeest behind them '],
#   ['Two giraffe and a ox standing in a field eating grass.'],
#   ['Giraffes and other safari animals graze in a sunlit field.']],
#  [['A clcok mounted to the side of a wall on the outside of a building.'],
#   ['A city block with a building and a clock'],
#   ['Buildings with a clock and lampposts along a street.'],
#   ['A clock is attached to the side of a building.'],
#   ['A clock protrudes high up on the side of a building.']],
#  [['A man standing in front of a microwave next to pots and pans.'],
#   ['A man displaying pots and utensils on a wall.'],
#   ['A man stands in a kitchen and motions towards pots and pans. '],
#   ['a man poses in front of some pots and pans '],
#   ['A man pointing to pots hanging from a pegboard on a gray wall.']],
#  [['A bunch of people at a table eating.'],
#   ['People sitting at a table with soup and drink.'],
#   ['People sitting at a table and eating soup.'],
#   ['Men and women sitting at a table with bowls of soup and drinks.'],
#   ['a number of people at a table with plates of food ']],
#  [['A bathroom with a toilet', ' sink', ' bath tub', ' and a small cabinet.'],
#   ['a bath room with a bath tub a toilet and a sink'],
#   ['A bathroom with lighting and a toilet and other things.'],
#   ['A large whirlpool tub in the corner of a tiled bathroom'],
#   ['A white bathroom with all of the necessities.']],
#  [['A skateboarder in the middle of a trick on a concrete rail.'],
#   ['A skateboarder rides a rail during a skill.'],
#   ['A skateboarder riding his skateboard along a railing'],
#   ['A man riding on his skateboard during the daytime. '],
#   ['A man dressed in warm clothes skateboarding in a public area.']],
#  [['The browned cracked crust of a baked berry pie.'],
#   ['A brown crust of pie with strawberry filing. '],
#   ['The top of a pie looks all crusty and good.'],
#   ['A close up of a cooked fruit flavored muffin.'],
#   ['An image of some sort of strawberry flaky pastery on display']],
#  [['A group of young people playing video games.'],
#   ['A group of people playing with a Nintendo Wii. '],
#   ['A group of people standing and holding wii remotes.'],
#   ['Friends playing video games together in the same room.'],
#   ['A bunch of young people are playing with the Wii.']],
#  [['A group of airplanes in the sky in formation. '],
#   ['The jets are flying through the air in unison.'],
#   ['A row of four trick Navy Planes flying in sequence.'],
#   ['The planes are all flying in the same direction.'],
#   ['a formation of fighter jets flying by in the air']],
#  [['Neatly folded dress shirts and a tie sit on top of a counter.'],
#   ["A pile of men's dress clothing on a table in a store. "],
#   ['a pile of folded cloths sit atop of each other '],
#   ['Shirts and a tie folded up sitting on a table. '],
#   ['the dress shirts are folded and matched with ties']],
#  [['A herd of oxen lounging in a field.'],
#   ['A bunch of bulls on a green pasture.'],
#   ['A herd of cows are resting in a meadow.'],
#   ['Longhorned bovine lying as a herd in a pasture.'],
#   ['A herd of cattle are resting on a grassy field.']],
#  [['A bunch of flowers sticking out of a glass vase.'],
#   ['THIS IS A VERY PRETTY PICTURE OF A VASE OF FLOWERS'],
#   ['a flower that is in some kind of jar'],
#   ['A vase full of flowers sitting beside a blue piece of pottery.'],
#   ['A fall arrangement of flowers has a raffia bow.']],
#  [['The red bus has an anime girl on it. '],
#   ['Anime themed bus traveling down a tree lined street.'],
#   ['a red blue and white bus riding down a empty street '],
#   ['The back of a bus in Japan with a Sailor Moon character on it.'],
#   ['A photo of the back of a public transportation bus with anime advertisement.']],
#  [['Stop sign at the intersection of two streets on a fall day. '],
#   ['A stop sign that has some street signs on top of it.'],
#   ['a stop sign that has some signs on top'],
#   ['Two street signs that are on top of a stop sign.'],
#   ['Traffic and directional signs are displayed on a city street.']],
#  [['Three men in military suits are sitting on a bench', ''],
#   ['Three persons with military attire seated on a bench'],
#   ['Three young men in decorated uniforms sit on a bench together.'],
#   ['a few guys sit next to each other on a bench '],
#   ['Three young men sitting on a bench wearing dress formals.']],
#  [['A man riding a horse in front of a fence.'],
#   ['a man on a white horse in a stable ridding'],
#   ['a man on a horse standing in side a white fence'],
#   ['A person in a fancy outfit riding on a big pretty horse.'],
#   ['A man riding on the back of a white horse.']],
#  [['Cat sitting on wood framed mirror looking down at own reflection.'],
#   ['A gold and white cat looking at their reflection in a mirror.'],
#   ['A cat sitting down and looking at itself in the mirror.'],
#   ['A curious cat staring at himself in the mirror.'],
#   ["The cats looks at it's reflection while sitting on a mirror. "]],
#  [['A group of people standing around a kitchen.'],
#   ['A woman laughing with a group of people standing in a ktichen'],
#   ['6 people gather and socialize in a kitchen.'],
#   ['These people are laughing while enjoying a beverage.'],
#   ['Group of young people laughing in the kitchen.']],
#  [['A couple of giraffe standing next to each other in a  forest.'],
#   ['Two giraffes in the wild on a sunny day'],
#   ['Two giraffes standing among low trees in an outdoor setting.'],
#   ['Two giraffes standing next to each other near trees'],
#   ['Two tall giraffes standing next to each other. ']],
#  [['Two people standing in a kitchen looking around. '],
#   ['A couple of men are standing in a kitchen'],
#   ['Two people looking at a large kitchen '],
#   ['An elderly man and woman looking around in a kitchen.'],
#   ['Two people standing close to each other while standing in a kitchen.']],
#  [['a person at a table eating pizza '],
#   ['A blond woman sitting at a table eating food wearing a t-shirt that says "Stop staring at my donuts".'],
#   ['A very pretty lady eating a big pizza.'],
#   ['A woman is wearing a donut shirt while eating donuts.'],
#   ['a woman eating while others are standing around']],
#  [['color photo of three zebra standing in all directions'],
#   ['Two zebras that are standing right next to one another.'],
#   ['A group of zebra standing next to each other.'],
#   ['two zebras are enbracing each other with their necks'],
#   ['Two zebras standing in a field lean their heads against each other.']],
#  [['The man is trying to hit the baseball during the game. '],
#   ['A player is up to bat in a baseball game.'],
#   ['People playing baseball while the pitcher is ready to pitch'],
#   ['A hitter',
#    ' catcher',
#    ' and umpire near home plate during a baseball game.'],
#   ['A group of men on a field playing baseball.']],
#  [['an image of a sandwhich that is not eaten'],
#   ['Two sandwiches on whole wheat bread filled with meat slices',
#    ' cheddar cheese slices',
#    ' alfalfa sprouts and green leafy lettuce.'],
#   ['A sandwich with a soda on top of a table.'],
#   ['a close up of a sandwich on a plate near a soda'],
#   ['A sandwich and can of soda on a table.']],
#  [['Three people walking down a sidewalk while holding umbrellas.'],
#   ['Three people walking down the sidewalk with umbrellas.'],
#   ['Three people walking with umbrellas in the rain.'],
#   ['Three men walking in the rain with umbrellas.'],
#   ['Three people walk down the street with their umbrellas protecting them from the rain.']],
#  [['there is a surfer flying a kite at the beach'],
#   ['A parasailer surfs the coast of a windy beach.'],
#   ['Person standing at the water flying a huge kite.'],
#   ['A person holding on to a para-sail standing in the surf.'],
#   ['The person is on the beach flying a kite. ']],
#  [['there is a white toilet and tile floors in the bathroom '],
#   ['a very clean toilet with black and white tiles '],
#   ['An open white toilet against a wall of white tiles and a black and white floor.'],
#   ['a white toilet in a bathroom with a checkers floor'],
#   ['A white toilet that has its seat up.']],
#  [['A young boy standing next to a green frisbee.'],
#   ['a young boy in a gray sweater throwing a green Frisbee in a park'],
#   ['a llittle boy in a sweater is throwing a frisbee'],
#   ['A young boy throwing a frisbee in a yard.'],
#   ['A young bow throws a Frisbee behind him']],
#  [['A young woman using a laptop computer while sitting on a bunk bed.'],
#   ['A person that is sitting in a bed facing out.'],
#   ['A young girl sits in the bottom bunk of her bunkbed.'],
#   ['A bedroom with bunk beds and the bathroom next door.'],
#   ['Three people live in one room who share a bathroom.']],
#  [['A side table with a lamp and books net to a home library.'],
#   ['This is one corner of a loving that contains a bookshelf with a lot of books.'],
#   ['A table with a lamp on top of it next to a couch.'],
#   ['There are plenty of books to read by the couch. '],
#   ['A book case with several books next to a lamp and couch.']],
#  [['A group of men playing a game of baseball on top of a baseball field.'],
#   ['Wide angled picture of a baseball field with many players.'],
#   ['A group of people that are standing on a baseball field.'],
#   ['A group of men on a field playing baseball.'],
#   ['A professional baseball game in progress with a runner on 1st base.']],
#  [['A large building with a clock on the front of it'],
#   ["A tall clock tower with a large clock on it's face."],
#   ['a clock on a building with  sky background'],
#   ['An image of a clock on a building.'],
#   ['An clock is encased in the wall of an older building.']],
#  [['The snowboarder has jumped high into the air from a snow ramp.'],
#   ['A person is hanging in the air near a building.'],
#   ['A person flying through the air on top of a snowboard.'],
#   ['An outside photo of signs', ' and lamp poles among the trees.'],
#   ['A snowboarder hitting a trick off a giant ramp.']],
#  [['A busy city street with many different vehicles.'],
#   ['A city street filled with lots of traffic and lights.'],
#   ['very many vehicle moving on the road with traffic lights'],
#   ['Cars are crossing paths in an intersection', ' nearing accident.'],
#   ['car traveling down a city street next to a gas station']],
#  [['a white bus is on a busy street'],
#   ['A view of a street of a bus', ' bikes and people walking. '],
#   ['A metal tube sculpture looking out on a city street.'],
#   ['A view of a bus and pedestrians on a busy city street from the top of a staircase.'],
#   ['A white bus parked in front of  building on the side of a road.']],
#  [['A small boat sits on the water next to a city.'],
#   ['A city scape that is seen from the other side of the river.'],
#   ['A city scene that was seen from the other side of a river.'],
#   ['A metropolitan city as viewed from the water. '],
#   ['A small boat is in the water in front of an elaborate looking city.']],
#  [['A stop sign along an empty road lined with a green fence.'],
#   ['Arabic stop sign on highway near major industrial installation.'],
#   ['A stop sign sits on a dirt corner near an asphalt road.'],
#   ['Looking down the paved road near a construction site in Saudi Arabia'],
#   ['a street sign sits next to a street ']],
#  [['A photo of a kitchen with focus on the oven.'],
#   ['Small kitchen with appliances',
#    ' cabinets',
#    ' dishes and other miscellaneous items'],
#   ['A kitchen with wooden cabinets and a microwave oven.'],
#   ['kitchen with a mini fridge', ' sink and toaster oven'],
#   ['A kitchen with multiple cups of different colors such as blue',
#    ' white',
#    ' and red.']],
#  [['an image of two elephants doing down the grass'],
#   ['Some elephants are standing in the middle of a field. '],
#   ['Two elephants in the field moving along during the day.'],
#   ["An elephant and it's baby in a field of grass."],
#   ['Two elephants walking in a grassy field next to a hill.']],
#  [['A display of a toilet and sink in a store. '],
#   ['Toilet and sink on display in a furniture store'],
#   ['A toilet with a sink on the back is displayed.'],
#   ['A store filled with bathroom equipment and accessories.'],
#   ['a white toilet with a brown lid and a sink behind it']],
#  [['A man wearing a hat and a gray jacket.'],
#   ['A man with a suit and tie and a fedora on.'],
#   ['A man wears a suit with a blue shirt and a multicolored tie.'],
#   ['A man in a suit and tie wearing a hat.'],
#   ['a man that is in a suite and a tie']],
#  [['A living room view of a couch', ' mirror', ' and vases.'],
#   ['A living area with a sofa', ' mirror and lamps.'],
#   ['A white couch sitting in a living room next to a mirror.'],
#   ['a sectional sofa in a front room with a bookshelf and mirror with two floor lamps and two vases of flowers on either side'],
#   ['A living room couch with a display of large mirror and flowers.']],
#  [['A woman standing next to a dog wearing a backpack on a beach.'],
#   ['A woman and a dog on a hike on a sunny day.'],
#   ['a person and their service dog standing on a mountain '],
#   ['There is a dog standing next to its master'],
#   ['A black and white dog stands beside a person.']],
#  [['A building with a clock on the front and side of it near other buildings'],
#   ['A view of two different tower structures at the eve of night.'],
#   ['The tower of the building has a clock displayed on the front of it.'],
#   ['Two tall buildings being lit in the night.'],
#   ['Picture of a tall tower behind a black silhouette']],
#  [['A family of elephants walking through tall grass.'],
#   ['A baby elephant elephant is walking along with grown elephants.'],
#   ['A large elephant walking with two smaller elephants'],
#   ['three elephants walking in a field and one is a baby'],
#   ['Two adults and one baby elephant walling the plains.']],
#  [["A smart phone with an image of a person on it's screen."],
#   ['A stack of 3 computers and a cell phone.'],
#   ['A stack containing three laptop computers and a smartphone.'],
#   ['Three laptops stacked on top of each other',
#    ' from largest to smallest with a cell phone on the top.'],
#   ['a desk with three electronics stacked on each other']],
#  [['People playing with kites outside in the desert.'],
#   ['A group of people at a park flying a kite. '],
#   ['A group of people flying a kite on a sandy beach'],
#   ['People on the beach flying kites in the wind.'],
#   ['A couple people out flying a kite on some sand.']],
#  [['A man talking on his phone in the public.'],
#   ['A man using a cell phone amongst a crowd of people.'],
#   ['A man in a crown wears a red jacket and is on the phone.'],
#   ['A man standing on a busy sidewalk while talking on his cellphone.'],
#   ['a man with a white beard and hat on a cellphone']],
#  [['A cheesy pizza sitting on top of a table.'],
#   ['This large pizza has a lot of cheese and tomato sauce.'],
#   ['A prepared pizza being served at a table.'],
#   ['A pizza with olive', ' cheese', ' tomato and onion.'],
#   ['Baked pizza with herbs displayed on serving tray at table.']],
#  [['A dog sitting on the inside of a white boat.'],
#   ['a dog sits on a boat floating in water'],
#   ['Dog forlornly looking out the back of a twin-hulled boat.'],
#   ['The dog is riding on the boat in the water.'],
#   ['a white boat is out on the water']],
#  [['A giraffe eating food from a very large rock.'],
#   ['A baby giraffe has its nose against a large rock.'],
#   ['A giraffe drinks from a puddle on top of a boulder in its enclosure. '],
#   ['A giraffe examines a rock in its enclosure.'],
#   ['A small giraffe sticks its nose on top of a large rock. ']],
#  [['Soriano lashes a double down the left field line '],
#   ['Two baseball players',
#    ' one with trying to hit a ball while the other trying to catch the ball'],
#   ['A player up to bat at a baseball game in a stadium.'],
#   ['A professional baseball player swinging a bat during a game.'],
#   ['A batter swings at the ball at a baseball game.']],
#  [['Children are in the living room playing a video game'],
#   ['Several children are doing exercises in a living room.'],
#   ['A group of females is waving their arms.'],
#   ['A bunch of young girls all have their arms up on a wooden floor.'],
#   ['Several children and one adult are doing exercises in a living room. ']],
#  [['A guy jumping with a tennis racket in his hand.'],
#   ['A man standing on a tennis court holding a racquet.'],
#   ['A guy holding a racket in a game of tennis.'],
#   ['A tennis player in mid air action on the court.'],
#   ['A man in black shirt and blue shorts playing a game of tennis.']],
#  [['Adult elephant standing next to wire fence outdoors.'],
#   ['An elephant walking through underbrush next to a fence.'],
#   ['A large elephant is staring in front of a fence.'],
#   ['A large elephant in a field with trees.'],
#   ['An elephant is standing next to a tree and a fence.']],
#  [['People on the shore as boats sit in the water.'],
#   ['A man walking next to a large blue round bench.'],
#   ['A bench that is shaped like a semi circle', ' with a man sitting in it.'],
#   ['a blue bike rack is by the grass'],
#   ['some people some benches grass water boats and trees']],
#  [['A man riding a motorcycle down a street with a person.'],
#   ['Two people riding together on a motorcycle down the road.'],
#   ['Two people on a motorcycle with another one in the background '],
#   ['A man and a woman riding on a motorcycle. '],
#   ['Two people on a motorcycle with another motorcycle in background.']],
#  [['A dog laying down with its bed on its head .'],
#   ['A dog laying down with a cushion over is head. '],
#   ['A brown dog laying on floor under a brown mat.'],
#   ['a dog under a dog bed on a white background'],
#   ['There is a dog playing with a dog bed']],
#  [['a close up of a child next to a cake with balloons'],
#   ['A baby sitting in front of a cake wearing a tie.'],
#   ['The young boy is dressed in a tie that matches his cake. '],
#   ['A child eating a birthday cake near some balloons.'],
#   ['A baby eating a cake with a tie around his/her neck with balloons in the background.']],
#  [['a large bus is up by the side of a curb'],
#   ['A group of people loading onto a bus.'],
#   ['people are getting onto a stopped City bus'],
#   ['this is a bus stopping in the middle of traffic'],
#   ['City bus with passengers boarding for Ballston Station.']],
#  [['A BRICK TOWER WITH A BIG CLOCK IN THE MIDDLE OF IT.'],
#   ['A large building with a metal clock on the front.'],
#   ['A clock is shown on the side of a building.'],
#   ['A church steeple clock with roman numerals set at 1:00. '],
#   ['A clock set onto the face of an old stone building.']],
#  [['two parking meters connectec onto one pole '],
#   ['A parking meter in front of a building piled in snow. '],
#   ['A couple of parking meters sitting in front of a building.'],
#   ['Double parking meter with expired time buried in snow'],
#   ['A parking meter sticking out of deep snow ']],
# ...
#   ['a large zebra that is walking on some grass'],
#   ['The zebra is eating the grass in the fence '],
#   ['A zebra displays its brilliant stripes while eating.']],
#  [['A white car is parked in the street at night time. '],
#   ['light streaks and a stop and go traffic light'],
#   ['A night scene of a traffic light in front of a parking lot.'],
#   ['A picture of the traffic going by at a high speed'],
#   ['A city street at night with a red traffic light.']],
#  [['A white refrigerator freezer sitting on a  hard wood floor.'],
#   ['A refrigerator and waste basket next to a wall.'],
#   ['There is no image that is on display to describe.'],
#   ['A tall thin refrigerator and a trash can.'],
#   ['a large refridgerator sitting on a wooden floor next to a trash can']],
#  [['Three people on the beach standing with surfboards.'],
#   ['Three people in suits are standing and holding surfboards.'],
#   ['A woman and two men in suits', ' standing on a beach holding surfboards.'],
#   ['Three people in suits standing on the beach with surfboards.'],
#   ['three people standing holding surf boards on a beach']],
#  [['A painting of a man herding sheep in the field.'],
#   ['A young boy is herding rams with a stick.'],
#   ['a number of animals in a field with trees near by'],
#   ['Herd of goats in grassy area with herder.'],
#   ['The 3D image shows a man herding a group of animals.']],
#  [['A women doubles team in tennis converse as they are on the court. '],
#   ['Two women stand next to each other on a court.'],
#   ['two women in white dresses playing tennis and fans'],
#   ['Tennis players cross paths on a grassy court with packed stands.'],
#   ['Tennis match in play with people in the stands watching.']],
#  [['People standing outside doorway with ribbon across it.'],
#   ['A group of people standing outside of a doorway with a ribbon on it.'],
#   ['A group of people stand outside a building at a ribbon cutting.'],
#   ['Some people are waiting in an open doorway'],
#   ['This is a picture of a house warming party.']],
#  [['A man covering his eyes next to cases of bananas'],
#   ['a person covering his face next to many boxes of bananas'],
#   ['A man standing beside a display of bananas in boxes.'],
#   ['A man standing with his hands over his eyes by a fruit stand.'],
#   ['A man covering his eyes while standing next to multiple boxes filled with bananas.']],
#  [['A blue bus driving down a city street.'],
#   ['A large blue bus is driving down a crowded street.'],
#   ['a citi bus parked in the street with buildings in teh background'],
#   ['A passenger bus that is driving down a street.'],
#   ['A blue bus makes its way down a narrow city street.']],
#  [['A peacock with very large feathers walking down a street.'],
#   ["A peacock is standing on a brick path with it's feathers fanned.  "],
#   ["A beautiful peacock with it's feathers spread while it stands on stones."],
#   ['A peacock with its feather out standing next to a stone wall.'],
#   ['A peacock with its tail fully open on a stone path. ']],
#  [['Heavy rain falls on a man holding a black umbrella.'],
#   ['People walking in the rain with open umbrellas in heavy rain.'],
#   ['A man is walking holding an umbrella in the snow'],
#   ['A person is holding an umbrella in a snowstorm.'],
#   ['a man walking with an umbrella on a very rainy day']],
#  [['A bunch of birds sitting in a bread basket.'],
#   ['Two birds perched on a bread basked on a table.'],
#   ['Two finch birds standing next to a basket of bread. '],
#   ['Birds are standing in a basket on the table.'],
#   ['three birds sitting on a bread basket near a newspaper']],
#  [["A dog holding a yellow frisbee in it's mouth."],
#   ['a dog that is standing on a brick pathway with a freez bee'],
#   ['A brown and white dog is holding a yellow Frisbee.'],
#   ["A brown and white dog with long ears holding a yellow frisbee in it's mouth."],
#   ['a dog is holding a yellow disc in its mouth']],
#  [['The park has a outside clock displayed. '],
#   ['A huge clock with roman numerals mounted on a wall.'],
#   ['A large brick structure with a clock on it'],
#   ['A brick sign for the Royal Observatory of Greenwich.'],
#   ['The Royal Observatory Greenwich sign has a strange machine that looks like a clock but is not one.']],
#  [['A living area with a fireplace', ' television and couch.'],
#   ['A stone wall with a fireplace built into it'],
#   ['A rock fireplace wall with built in television and wood receptacle'],
#   ['A couch and a television in a living room.'],
#   ['A stone fireplace with entertainment center and mantle.']],
#  [['A large jetliner lading on a runway at an airport.'],
#   ['men digging some holes close to a runway with a plane'],
#   ['Two workers are digging near an airport runway.'],
#   ['Two workers digging holes in the snow near an airport.'],
#   ['Two men digging holes next to an airport']],
#  [['A couple of double high buses that are in the street.'],
#   ['two public transit buses on a city street '],
#   ['A man walking down a street past a double decker bus.'],
#   ['a couple of buses that are parked next to each other'],
#   ['Two double-decker buses going in opposite directions on a road.']],
#  [['A boat traveling down a lake next to a shoreline.'],
#   ['A boat is parked ashore without a passenger.'],
#   ['A small boat with a motor sitting on the edge of a beach.'],
#   ['A motor boat next to a beach and others in the background'],
#   ['A small boat with equipment inside of it washed up on shore.']],
#  [['Mountain sheep standing in outdoor natural setting area.'],
#   ['The sheep are grazing on grass in the field. '],
#   ['A black and white photo of tow rams on a rocky hill.'],
#   ['a couple of sheep standing up on a small hill'],
#   ['Black and white photograph of horned sheep by a large rock']],
#  [['Woman wearing polka dot stockings and pink dress posing with an umbrella.'],
#   ['A beautiful young woman holding a white bag and an umbrella.'],
#   ['A woman standing out side while holding an umbrella.'],
#   ['a female in a red dress and a tan umbrella and some trees'],
#   ['An attractive young woman holding an umbrella under a tree.']],
#  [['A woman holding a piece of chocolate cake at a table.'],
#   ['Two people are putting candles on a birthday cake. '],
#   ['A group of people around a chocolate cake with candles.'],
#   ['Some people gathered at a table with a pretty cake.'],
#   ['The group of people are getting ready to eat cake.']],
#  [['A man is making a phone call while surrounded by balloons. '],
#   ['A shirtless young man is shown at some type of street party with numerous baloons attached to his body.'],
#   ['A man holding multiple long skinny balloons around his head while talking on a cellular phone.'],
#   ['a man without a shirt and some white blue and pink baloons'],
#   ['Man with no shirt and lots of balloons. ']],
#  [['A large pizza placed on top of table next to a wineglass '],
#   ['A rectangle pizza sitting on top of a wooden cutting board.'],
#   ['A rectangular pizza served on a wooden cutting board'],
#   ['A pizza is on top of a cutting board on a table.'],
#   ['An oblong pizza with mushrooms is on a cutting board.']],
#  [['a big dog leans out the window of a car'],
#   ['A very cute big dog hanging out of a car window.'],
#   [' a dog sticking his head out the window of a moving vehicle'],
#   ['A yellow lab is looking at the camera man from the truck window.'],
#   ['A dog that is looking out a of car window.']],
#  [['A parade on the street with a person riding an elephant.'],
#   ['a parade with an elephant wearing a sign that says" i love new york"'],
#   ['Few persons are seen on zebra crossing on road and an elephant with a banner is there.'],
#   ['a group of people walking down the street in a parade witha elephant that says i love new york'],
#   ['A man is riding an elephant with and "I love NY" sign.']],
#  [['A fire hydrant is painted in a patriotic theme.'],
#   ['A fire hydrant on a sidewalk next to grass '],
#   ['a little red and blue fire hydran next to a sidewalk'],
#   ['The red and blue fire hydrant has stars on it.'],
#   ['A red and blue fire hydrant sitting in the middle of a sidewalk.']],
#  [['A woman talks on her cell phone on the busy sidewalk.'],
#   ['People with umbrellas over their head and another on the phone.'],
#   ['A women who is on her cell phone outside.'],
#   ['A woman talking on her phone in the rain'],
#   ['A woman standing on a crowded sidewalk talking on a cell phone.']],
#  [['The police officers are sitting together and eating food.'],
#   ['A group of policemen sitting at a lunch meeting.'],
#   ['A group of people that are sitting around a table.'],
#   ['A group of men and emergency responders surrounding a table.'],
#   ['A bunch of cops are sitting and eating at a table']],
#  [['A lady is in the hospital and sitting in a chair smiling.'],
#   ['a lady sitting in a chair in the hospital'],
#   ['Woman with an I.V. in her arm reclining in a hospital room.'],
#   ['A smiling woman reclining in a hospital bed.'],
#   ['A smiling woman sitting up in a hospital bed.']],
#  [['Several boats in the water near an amusement park. '],
#   ['There are a lot of boats on the lake shore.'],
#   ['Four boats are in the water outside of the carnival. '],
#   ['Boats float in the water across from an amusement park.'],
#   ['there are many boats in the water by this carnival']],
#  [['A large convex mirror mounted to a brick wall.'],
#   ['A round mirror is on a wall with a reflection in it.'],
#   ['a mirror on the wall showing a reflection of train and a wall'],
#   ['A round mirror for seeing around corners is attached to the shiny tiles of the wall.'],
#   ['A reflective mirror at the junction of two hallways.']],
#  [['A man sitting in a chair holding a yellow umbrella.'],
#   ['A man and woman selling merchandise on a table.'],
#   ['A man under a umbrella and a woman eating food.'],
#   ['Two older people eating while sitting next to a table at a flea market.'],
#   ['An elderly man and woman sitting outside next to a table.']],
#  [['A man riding a motorcycle down the middle of a street.'],
#   ['a pair of motorcycles going down a street with cars in the background'],
#   ['A man rides a motorcycle in front of another biker down a city road.'],
#   ['A man with a bandana is riding a motorcycle.'],
#   ['A man wearing blue jeans rides a blue motorcycle near a red motorcycle.']],
#  [['three zebras and a gazelle drinking at a watering hole'],
#   ['THREE ZEBRAS AND ONE GAZELLE GRAZING TOGETHER '],
#   ['Three zebras and an antelope drinking from a small pond.'],
#   ['Zebras and a gazelle in a wildlife park'],
#   ['Three zebra grazing in the grass on a sunny day.']],
#  [['A pile of feces sits on the back of a public restroom toilet.'],
#   ['A toilet is splattered with feces on the rim.'],
#   ['a toilet with a digususting mess by the toilet seat'],
#   ['A dirty toilet seat in a public bathroom. '],
#   ['there is a toilet with dirt on it']],
#  [['The sky is cloudy over a stop sign.'],
#   ['A traffic sign near a high grass field near a road. '],
#   ['Under cloudy skies', ' a stop sign is beside a fenced field.'],
#   ['A field that has a fence around it.'],
#   ['Dark clouds spreading across a field and a house.']],
#  [['A man with blue jersey holding a baseball bat.'],
#   ['a close up of a baseball player holding a bat on the field'],
#   ['an image of a baseball player about to bat'],
#   ['A baseball player doing warm up exercises before going up to bat.'],
#   ['a baseball player standing in the grass with a bat in his hand ']],
#  [['A cat is using the toilet in a white tile bathroom.'],
#   ['There is a cat standing in a toilet.'],
#   ['A cat climbs out of an open toilet. '],
#   ['A cat has learned to use a toilet made for people. '],
#   ['a cat with its hind legs in a toilet']],
#  [['A group of planes sitting on a runway', ' in the day.'],
#   ['An outside view of airplanes and buildings at an airport.'],
#   ['A view of three plane tails on an airport tarmac'],
#   ['The various airplanes are waiting for repairs at the terminals.'],
#   ['An airport with several planes at gates and trucks on the tarmac.']],
#  [['A baby girl with beautiful blue eyes standing next to a brown teddy bear.'],
#   ['a toddler girl selfie with her stuffed bear'],
#   ['A blue eyed baby looks at the camera.'],
#   ['A toddler with a bow in her hair.'],
#   ['A young child looks into the camera with wide eyes. ']],
#  [['Two bags are full of fruits on the table.'],
#   ['Two baskets full of oranges on a table with a note.'],
#   ['two baskets of oranges on a table near a written note '],
#   ['A note that urges people to take a vitamin C break next to two baskets of oranges.'],
#   ['a note sitting between a couple baskets of oranges ']],
#  [['A bus is driving on a wet road with many green trees on the roadside.'],
#   ['A bus is traveling through a street surrounded by trees.'],
#   ['A red bus driving down the road with its lights on.'],
#   ['A city bus that is traveling down a wet country road. '],
#   ['A transit bus coming down a street with a large wooded side area.']],
#  [['A group of vehicles driving down a city street.'],
#   ['A building is near cars under a traffic light.'],
#   ['a bunch of cars sit parked at a traffic light '],
#   ['A traffic light with a few cars going over the crosswalk.'],
#   ['A street with cars moving down it past an intersection.']],
#  [['Young woman with long brown hair in very dark grey jump top holding electronic instrument like a remote control.'],
#   ['A young woman holding a video game remote'],
#   ['A beautiful young lady holding a Nintendo Wii game controller.'],
#   ['A young woman stands with a Wii remote in her hand.'],
#   ['Girl standing with a Wii controller in her hand']],
#  [['A tray with a donut and coffee on it '],
#   ['A brown tray topped with a doughnut and a cup of coffee.'],
#   ['A tray displaying a donut and coffee is shown while a person checks their cell phone.'],
#   ['A tray of food sits on a table.'],
#   ['A tray with a doughnut and a cup of coffee on it.']],
#  [['A young boy is playing tennis at the tennis courts.'],
#   ['a boy that has a tennis racket in hand'],
#   ['a young boy holding a tennis racket '],
#   ['A young boy holding a tennis racket while standing on a court.'],
#   ['Child holding tennis racket in middle of court looking to get call']],
#  [['A yellow duck boat floating on top of a lake.'],
#   ['A lake with a paddle boat and a blue sky.'],
#   ['A yellow swan boat ride on a body of water under a cloudless sky.'],
#   ['A tour boat on a man made lake under a blue sky'],
#   ['A swan looking paddle boat is out on the water.']],
#  [['A couple of birds sitting on a tree', ' with a blurry background.'],
#   ['Two birds perched on the branch of a tree.'],
#   ['A couple of hummingbirds sitting on a tree branch.'],
#   ['there are two small birds that are standing on a tree branch'],
#   ['Two birds perched on a tree branch outside. ']],
#  [['A dog wearing a hat and sitting in the grass.'],
#   ['A sweet dog is wearing a white hat.'],
#   ['A small yellow dog wearing a white hat.'],
#   ['A dog is sitting in the grass', ' wearing a hat. '],
#   ['A dog with a white hat at the field']],
#  [['A man and woman holding electronic devices in their hands.'],
#   ['Two children playing video games while a man talks on the phone.'],
#   ['a man on a phone and two little girls playing a video game'],
#   ['a group of people standing in a room playing a video game '],
#   ['one person on a cellular phone looking at a monitor screen next to a person holding a game controller in front of the same monitor']],
#  [['a group of young people getting ready to go ski'],
#   ['A group of people have backpacks as they stand on snow skis in the snow.'],
#   ['A group of skiers are gathered together as they get ready to ski.'],
#   ['Several people in their ski gear are in the snow. '],
#   ['four skiers ready to ski down a snowy mountain'],
#   []],
#  [['The people are sitting on the dock beside of the water'],
#   ['The ships are out in the water in a distance.'],
#   ['A boardwalk next to the water with people and birds walking and setting.'],
#   ['Two people who are sitting next to a bench on a pier.'],
#   ['some people are sitting out by the water']],
#  ...]
